# %%
# 순위 제목 저자 역자 출판사 발행일 가격

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
main = 'http://book.interpark.com'
url = '/display/collectlist.do?_method=bestsellerHourNew&bookblockname=b_gnb&booklinkname=%BA%A3%BD%BA%C6%AE%C1%B8&bid1=w_bgnb&bid2=LiveRanking&bid3=main&bid4=001'

# %%
response = requests.get(main+url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>싸니까 믿으니까 인터파크도서</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="인터파크도서, 인터넷 서점, eBook, 비스킷탭, 음반, DVD, 중고책, 중고책서점, 신간도서, 국내도서, 외국도서, 추천도서" name="keywords"/>
# <meta content="문학은 인터파크 도서!" name="description"/>
# <meta content="no-cache" http-equiv="Cache-Control">
# <meta content="0" http-equiv="Expires">
# <meta content="no-cache" http-equiv="Pragma">
# <link href="http://bimage.interpark.com/interpark.ico" rel="shortcut icon"/>
# <meta content="no" http-equiv="imagetoolbar">
# <script type="text/javascript">
#         var isFancyAlert = false;    // IMFS에서는 msgAlert 기능을 비활성화시킴
#         var imfsSSLDomain = "https://book.interpark.com"; // com.interpark.util.web.ServletUtils.IMFS_URL_SSL 값을 사용하였으나, Fix 처리 한듯.
#     </script>
# <script src="http://book.interpark.com/static/js/common.js" type="text/javascript"></script>
# ...

# %% [markdown]
# # 원하는 데이터 찾기

# %%
lis = soup.select_one('.rankBestContentList').select('ol > li')
lis
# Out:
# [<li>
#  <!-- listItem | singleType or setType :: start -->
#  <div class="listItem singleType">
#  <div class="cover">
#  <div class="coverImage">
#  <label>
#  <a href="/product/BookDisplay.do?_method=detail&amp;sc.shopNo=0000400000&amp;sc.prdNo=356522531&amp;sc.saNo=003003001&amp;bid1=Best_zone&amp;bid2=LiveRanking&amp;bid3=PRD&amp;bid4=001" target="_blank">
#  <span class="checkBox">
#  <input name="_KEY" type="checkbox" value="356522531"/>
#  </span>
#  <img alt="세이노의 가르침" src="http://bimage.interpark.com/goods_image/2/5/3/1/356522531s.jpg"/>
#  <i class="decoFront"></i>
#  </a>
#  </label>
#  </div>
#  <div class="coverOption">
#  <ul>
#  <li class="cart">
#  <a class="cartGo" href="#" value="356522531"><span>CART</span></a>
#  </li>
#  <li class="buy">
#  <a href="javascript:directOrd('356522531');"><span>BUY</span></a>
#  </li>
#  </ul>
#  </div>
#  <div class="rankNumber digit2">
#  <span class="rankBtn_ctrl rkNum_B01"></span>
#  </div>
#  </div>
#  <div class="itemIcon">
# ...

# %%
li = lis[0]

# %%
# 순위
rank = ''
rank_spans = li.select('.rankBtn_ctrl')
rank_spans
for span in rank_spans:
    rank += span['class'][1][-1]
int(rank)
# Out:
# 1

# %%
# # 1~9 순위
# rank = int(li.select_one('.rankBtn_ctrl')['class'][1][-1])

# # 10~15 순위
# element = '<div class="rankNumber digit2"><span class="rankBtn_ctrl rkNum_M01 "></span><span class="rankBtn_ctrl rkNum_M01 "></span></div>'
# mini_soup = BeautifulSoup(element)

# rank_data = li.select('.rankBtn_ctrl')
# if len(li)

# %%
# 제목
title = li.select_one('.itemName').get_text().strip()
title
# Out:
# '세이노의 가르침'

# %%
# 저자
author = li.select_one('.author').get_text().strip()
author
# Out:
# '세이노'

# %%
# 출판사
company = li.select_one('.company').get_text().strip()
company
# Out:
# '데이원'

# %%
# 가격
price = int(li.select_one('.price > em').get_text().replace(',', ''))
price
# Out:
# 6480

# %%
# 순위 제목 저자 출판사 가격
# 
# 역자 쪽수 발행일

# %% [markdown]
# # 링크 연결

# %%
sub = li.select_one('label > a')['href']
sub
# Out:
# '/product/BookDisplay.do?_method=detail&sc.shopNo=0000400000&sc.prdNo=356522531&sc.saNo=003003001&bid1=Best_zone&bid2=LiveRanking&bid3=PRD&bid4=001'

# %%
response = requests.get(main+sub, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title>싸니까 믿으니까 인터파크도서</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="인터파크도서, 인터넷 서점, eBook, 비스킷탭, 음반, DVD, 중고책, 중고책서점, 신간도서, 국내도서, 외국도서, 추천도서" name="keywords"/>
# <meta content="문학은 인터파크 도서!" name="description"/>
# <meta content="no-cache" http-equiv="Cache-Control">
# <meta content="0" http-equiv="Expires">
# <meta content="no-cache" http-equiv="Pragma">
# <link href="https://sslimage.interpark.com/interpark.ico" rel="shortcut icon"/>
# <meta content="no" http-equiv="imagetoolbar">
# <script type="text/javascript">
#         var isFancyAlert = false;    // IMFS에서는 msgAlert 기능을 비활성화시킴
#         var imfsSSLDomain = "https://book.interpark.com"; // com.interpark.util.web.ServletUtils.IMFS_URL_SSL 값을 사용하였으나, Fix 처리 한듯.
#     </script>
# <script src="/static/js/common_ssl.js" type="text/javascript"></script>
# ...

# %%
bInfo_Detail = soup.select('.bInfo_txt > li')
bInfo_Detail
# Out:
# [<li>저 : <a href="#" onclick='fn_wiseLogRedirect("infor","basic_inform","writer","http://bsearch.interpark.com/dsearch/book.jsp?sch=all&amp;sc.shopNo=&amp;bookblockname=s_main&amp;booklinkname=s_main&amp;query=세이노","_blank");return false;'>세이노</a></li>,
#  <li>출판사 : <a href="#" id="hdelvMafcEntrNm" onclick='fn_wiseLogRedirect("infor","basic_inform","publisher","http://bsearch.interpark.com/dsearch/book.jsp?sch=all&amp;query=데이원","_blank");return false;'>데이원</a></li>,
#  <li>발행 : 2023년 03월 02일</li>,
#  <li>쪽수 : 0</li>,
#  <li>제품구성 : 전1권</li>,
#  <li>ISBN : 9791168473690</li>]

# %%
for li in bInfo_Detail:
    print(li.get_text())
# Out:
# 저 : 세이노
# 출판사 : 데이원
# 발행 : 2023년 03월 02일
# 쪽수 : 0
# 제품구성 : 전1권
# ISBN : 9791168473690

# %%
author = '-'
trans = '-'
for li in bInfo_Detail:
    text = li.get_text().strip()
    if "발행 : " in text:
        date = text.split(':')[1].strip()
        date = re.sub('[^0-9]', '',date)
    elif "쪽수 : " in text:
        page = int(text.split(":")[1].strip())
    elif "역 : " in text:
        trans = text.split(":")[1].strip()
    elif "저 : " in text:
        author = text.split(":")[1].strip()

# %%
print(date, page, trans, author)
# Out:
# 20230302 0 - 세이노

# %% [markdown]
# # 페이지에 있는 모든 데이터 추출(tqdm)

# %%
# # 발행일
# date = bInfo_Detail[2].get_text().split(":")[1].strip()
# date
# Out:
# '2023년 03월 02일'

# %%
# # 쪽수
# page = bInfo_Detail[3].get_text().split(":")[1].strip()
# page
# Out:
# '0'

# %%
# # 역자(있으면 가져오고 없으면 '-')
# durwk = bInfo_Detail[3].get_text().split(":")[1].strip()

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
main = 'http://book.interpark.com'
url = '/display/collectlist.do?_method=bestsellerHourNew&bookblockname=b_gnb&booklinkname=%BA%A3%BD%BA%C6%AE%C1%B8&bid1=w_bgnb&bid2=LiveRanking&bid3=main&bid4=001'

response = requests.get(main+url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

lis = soup.select_one('.rankBestContentList').select('ol > li')

lines = []
for li in  lis:
    rank = ''
    rank_spans = li.select('.rankBtn_ctrl')
    rank_spans
    for span in rank_spans:
        rank += span['class'][1][-1]
    int(rank)
    title = li.select_one('.itemName').get_text().strip()
    author = li.select_one('.author').get_text().strip()
    company = li.select_one('.company').get_text().strip()
    price = int(li.select_one('.price > em').get_text().replace(',', ''))
    
    sub = li.select_one('label > a')['href']
    response = requests.get(main+sub, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    bInfo_Detail = soup.select('.bInfo_txt > li')
    date = bInfo_Detail[2].get_text().split(":")[1].strip()
    page = bInfo_Detail[3].get_text().split(":")[1].strip()
    lines.append([rank, title, author, company, price, date, page])
lines
# Out:
# [['1', '세이노의 가르침', '세이노', '데이원', 6480, '2023년 03월 02일', '0'],
#  ['2', '메리골드 마음 세탁소', '윤정은', '북로망스', 13500, '2023년 03월 06일', '272'],
#  ['3', '영어책 한 권 외워봤니?', '', '위즈덤하우스', 12600, '0', '9788960863132'],
#  ['4', '장하준의 경제학 레시피', '장하준', '부키', 16200, '2023년 03월 30일', '376'],
#  ['5',
#   '이미 늦었다고 생각하는 당신을 위한 김미경의 마흔 수업',
#   '김미경',
#   '어웨이크북스',
#   16200,
#   '2023년 02월 15일',
#   '300'],
#  ['6',
#   '괜찮아, 그 길 끝에 행복이 기다릴 거야',
#   '손미나',
#   '코알라컴퍼니',
#   17100,
#   '2023년 04월 05일',
#   '296'],
#  ['6', '살 때, 팔 때, 벌 때', '강영현', '21세기북스', 19800, '2023년 02월 28일', '268'],
#  ['6',
#   '브라질에 비가 내리면 스타벅스 주식을 사라',
#   '피터 나바로/이창식 역/윤지호 감수',
#   '에프엔미디어',
#   16200,
#   '윤지호',
#   '에프엔미디어'],
#  ['9', '내면소통', '김주환', '인플루엔셜', 29700, '2023년 02월 27일', '768'],
#  ['10', '표류하는 세계', '스콧 갤러웨이', '리더스북', 17820, '2023년 04월 01일', '324'],
#  ['10', 'K 배터리 레볼루션', '박순혁', '지와인', 17100, '2023년 02월 20일', '0'],
#  ['10', '불편한 편의점 2(단풍 에디션)', '김호연', '나무옆의자', 12600, '2022년 08월 10일', '320'],
#  ['10',
# ...

# %%
df = pd.DataFrame(lines, columns=['순위', '제목', '저자', '출판사', '가격', '발행일', '쪽수'])
df
# Out:
#     순위                                       제목                       저자  \
# 0    1                                 세이노의 가르침                      세이노
# 1    2                              메리골드 마음 세탁소                      윤정은
# 2    3                            영어책 한 권 외워봤니?
# 3    4                             장하준의 경제학 레시피                      장하준
# 4    5           이미 늦었다고 생각하는 당신을 위한 김미경의 마흔 수업                      김미경
# 5    6                   괜찮아, 그 길 끝에 행복이 기다릴 거야                      손미나
# 6    6                            살 때, 팔 때, 벌 때                      강영현
# 7    6                  브라질에 비가 내리면 스타벅스 주식을 사라      피터 나바로/이창식 역/윤지호 감수
# 8    9                                     내면소통                      김주환
# 9   10                                  표류하는 세계                  스콧 갤러웨이
# 10  10                               K 배터리 레볼루션                      박순혁
# 11  10                        불편한 편의점 2(단풍 에디션)                      김호연
# ...

# %%
from tqdm.notebook import tqdm

# %%
lines = []
for li in tqdm(lis):
    rank = ''
    rank_spans = li.select('.rankBtn_ctrl')
    rank_spans
    for span in rank_spans:
        rank += span['class'][1][-1]
    int(rank)
    title = li.select_one('.itemName').get_text().strip()
    company = li.select_one('.company').get_text().strip()
    price = int(li.select_one('.price > em').get_text().replace(',', ''))
    
    sub = li.select_one('label > a')['href']
    response = requests.get(main+sub, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    bInfo_Detail = soup.select('.bInfo_txt > li')      
    author = '-'
    trans = '-'
    for li in bInfo_Detail:
        text = li.get_text().strip()
        if "발행 : " in text:
            date = text.split(':')[1].strip()
            date = re.sub('[^0-9]', '',date)
        elif "쪽수 : " in text:
            page = int(text.split(":")[1].strip())
        elif "역 : " in text:
            trans = text.split(":")[1].strip()
        elif "저 : " in text:
            author = text.split(":")[1].strip()
    
    lines.append([rank, title, author, trans, company, page, date, price])
lines
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# [['1', '세이노의 가르침', '세이노', '-', '데이원', 0, '20230302', 6480],
#  ['2', '메리골드 마음 세탁소', '윤정은', '-', '북로망스', 272, '20230306', 13500],
#  ['3', '장하준의 경제학 레시피', '장하준', '-', '부키', 376, '20230330', 16200],
#  ['4',
#   '이미 늦었다고 생각하는 당신을 위한 김미경의 마흔 수업',
#   '김미경',
#   '-',
#   '어웨이크북스',
#   300,
#   '20230215',
#   16200],
#  ['4', '영어책 한 권 외워봤니?', '-', '-', '위즈덤하우스', 0, '20170111', 12600],
#  ['6', '괜찮아, 그 길 끝에 행복이 기다릴 거야', '손미나', '-', '코알라컴퍼니', 296, '20230405', 17100],
#  ['7', '한국형 가치투자', '김민국, 최준철', '-', '이콘', 296, '20230315', 16200],
#  ['7', 'K 배터리 레볼루션', '박순혁', '-', '지와인', 0, '20230220', 17100],
#  ['7', '불편한 편의점 2(단풍 에디션)', '김호연', '-', '나무옆의자', 320, '20220810', 12600],
#  ['10',
#   '브라질에 비가 내리면 스타벅스 주식을 사라',
#   '피터 나바로',
#   '이창식',
#   '에프엔미디어',
#   0,
#   '20220425',
#   16200],
#  ['11', '살 때, 팔 때, 벌 때', '강영현', '-', '21세기북스', 268, '20230228', 19800],
#  ['11', '내면소통', '김주환', '-', '인플루엔셜', 768, '20230227', 29700],
# ...

# %%
df = pd.DataFrame(lines, columns=['순위', '제목', '저자', '역자', '출판사', '쪽수', '발행일', '가격'])
df
# Out:
#     순위                              제목                            저자   역자  \
# 0    1                        세이노의 가르침                           세이노    -
# 1    2                     메리골드 마음 세탁소                           윤정은    -
# 2    3                    장하준의 경제학 레시피                           장하준    -
# 3    4  이미 늦었다고 생각하는 당신을 위한 김미경의 마흔 수업                           김미경    -
# 4    4                   영어책 한 권 외워봤니?                             -    -
# 5    6          괜찮아, 그 길 끝에 행복이 기다릴 거야                           손미나    -
# 6    7                        한국형 가치투자                      김민국, 최준철    -
# 7    7                      K 배터리 레볼루션                           박순혁    -
# 8    7               불편한 편의점 2(단풍 에디션)                           김호연    -
# 9   10         브라질에 비가 내리면 스타벅스 주식을 사라                        피터 나바로  이창식
# 10  11                   살 때, 팔 때, 벌 때                           강영현    -
# 11  11                            내면소통                           김주환    -
# ...

# %%
df.to_csv("인터파크 크롤링 2.csv", index=False)
