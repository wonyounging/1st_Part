# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
url = 'https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84'

# %%
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, )

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="win chrome" lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="영화순위 – Daum 검색" property="og:title"/>
# <meta content="https://search.daum.net/search?w=tot&amp;q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84" property="og:url"/>
# <meta content="Daum 검색에서 영화순위에 대한 최신정보를 찾아보세요." property="og:description"/>
# <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" property="og:image"/>
# <meta content="다음검색" property="og:site_name"/>
# <title>영화순위 – Daum 검색</title>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="Daum" type="application/opensearchdescription+xml"/>
# ...

# %%
movieInfoList = soup.find('ol', attrs={'class':'movie_list'}).find_all('li')

# %%
movieInfoList
# Out:
# [<li> <div class="wrap_thumb"> <a class="thumb" href="?w=tot&amp;q=%EC%8A%88%ED%8D%BC%20%EB%A7%88%EB%A6%AC%EC%98%A4%20%EB%B8%8C%EB%9D%BC%EB%8D%94%EC%8A%A4&amp;DA=MOR&amp;rtmaxcoll=EM1&amp;scckey=MV%7C%7C154241" onclick='smartLog(this, "dc=MOR&amp;p=4&amp;r=1&amp;rc=1&amp;pg=1&amp;d=154241", event);'> <img alt="" class="thumb_img" height="164" is-person-img="false" src="https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F8876ecefc861afc397a9943ab781bdf0316c4983" width="116"/> <span class="num_rank"><span class="img_number num_rank01">1위</span></span> </a> </div> <div class="wrap_cont cont_type2"> <div class="info_tit"> <a class="tit_main" href="?w=tot&amp;q=%EC%8A%88%ED%8D%BC%20%EB%A7%88%EB%A6%AC%EC%98%A4%20%EB%B8%8C%EB%9D%BC%EB%8D%94%EC%8A%A4&amp;DA=MOR&amp;rtmaxcoll=EM1&amp;scckey=MV%7C%7C154241" onclick='smartLog(this, "dc=MOR&amp;p=3&amp;r=1&amp;rc=1&amp;pg=1&amp;d=154241", event);'>슈퍼 마리오 브라더스</a> </div> <dl class="dl_comm star_comp_s"> <
# ...

# %%
movieInfo = movieInfoList[0]

# %%
movieRank = movieInfo.find('span', attrs={'class':'num_rank01'}).get_text()
movieRank
# Out:
# '1위'

# %%
movieTitle = movieInfo.find('a', attrs={'class':'tit_main'}).string
movieTitle
# Out:
# '슈퍼 마리오 브라더스'

# %%
movieScore = movieInfo.find('em', attrs={'class':'rate'}).string
movieScore
# Out:
# '8.4'

# %%
movieScoreCnt = movieInfo.find('a', attrs={'class':'link_count'}).text
movieScoreCnt
# Out:
# '18명 참여'

# %%
movieOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})
movieOpenDate[1].text.strip().replace('.', '/')
# Out:
# '2023/04/26/'

# %%
movieTicketSales = movieInfo.find_all('dd', attrs={'class':'cont'})
movieTicketSales[0].text.strip()
# Out:
# '24.4%'

# %%
movieInfo.find_all('dd', attrs={'class':'cont'})[1].get_text().replace('.', '/')
# Out:
# ' 2023/04/26/ '

# %%
movieInfo.find_all('dd', attrs={'class':'cont'})[0].get_text()
# Out:
# '0.2%'

# %%
movie_1 = []
for m in movieInfo:
    movie_1.append({
        '순위' : movieInfo.find('span', attrs={'class':'num_rank01'}).get_text(),
        '제목' : movieInfo.find('a', attrs={'class':'tit_main'}).string,
        '평점' : movieInfo.find('em', attrs={'class':'rate'}).string,
        '참여 인원수' : movieInfo.find('a', attrs={'class':'link_count'}).text,
        '개봉 날짜' : movieInfo.find_all('dd', attrs={'class':'cont'})[1].get_text().strip().replace('.', '/'),
        '예매율' : movieInfo.find_all('dd', attrs={'class':'cont'})[0].text
    })

# %%
movie_1
# Out:
# [{'순위': '1위',
#   '제목': '슈퍼 마리오 브라더스',
#   '평점': '8.4',
#   '참여 인원수': '18명 참여',
#   '개봉 날짜': '2023/04/26/',
#   '예매율': '24.4%'},
#  {'순위': '1위',
#   '제목': '슈퍼 마리오 브라더스',
#   '평점': '8.4',
#   '참여 인원수': '18명 참여',
#   '개봉 날짜': '2023/04/26/',
#   '예매율': '24.4%'},
#  {'순위': '1위',
#   '제목': '슈퍼 마리오 브라더스',
#   '평점': '8.4',
#   '참여 인원수': '18명 참여',
#   '개봉 날짜': '2023/04/26/',
#   '예매율': '24.4%'},
#  {'순위': '1위',
#   '제목': '슈퍼 마리오 브라더스',
#   '평점': '8.4',
#   '참여 인원수': '18명 참여',
#   '개봉 날짜': '2023/04/26/',
#   '예매율': '24.4%'},
#  {'순위': '1위',
#   '제목': '슈퍼 마리오 브라더스',
#   '평점': '8.4',
#   '참여 인원수': '18명 참여',
#   '개봉 날짜': '2023/04/26/',
#   '예매율': '24.4%'},
#  {'순위': '1위',
#   '제목': '슈퍼 마리오 브라더스',
#   '평점': '8.4',
#   '참여 인원수': '18명 참여',
#   '개봉 날짜': '2023/04/26/',
#   '예매율': '24.4%'},
#  {'순위': '1위',
#   '제목': '슈퍼 마리오 브라더스',
#   '평점': '8.4',
#   '참여 인원수': '18명 참여',
#   '개봉 날짜': '2023/04/26/',
#   '예매율': '24.4%'}]

# %%
movie_30 = []
for m in range(0, len(movieInfoList)):
    movieInfo = movieInfoList[m]
    movie_30.append({
        '순위' : movieInfo.find('span', attrs={'class':'num_rank'}).get_text(),
        '제목' : movieInfo.find('a', attrs={'class':'tit_main'}).string,
        '평점' : movieInfo.find('em', attrs={'class':'rate'}).string,
#         '참여 인원수' : movieInfo.find('a', attrs={'class':'link_count'}),
#         '개봉 날짜' : movieInfo.find_all('dd', attrs={'class':'cont'})[1].text().strip().replace('.', '/'),
        '예매율' : movieInfo.find_all('dd', attrs={'class':'cont'})[0].text
    })

# %%
movie_30
# Out:
# [{'순위': '1위', '제목': '슈퍼 마리오 브라더스', '평점': '8.4', '예매율': '24.4%'},
#  {'순위': '2위', '제목': '존 윅 4', '평점': '8.2', '예매율': '15.7%'},
#  {'순위': '3위', '제목': '드림', '평점': '9.4', '예매율': '11.2%'},
#  {'순위': '4위', '제목': '렌필드', '평점': '7.5', '예매율': '8.5%'},
#  {'순위': '5위', '제목': '옥수역귀신', '평점': '6.1', '예매율': '7.1%'},
#  {'순위': '6위', '제목': '인셉션', '평점': '8.7', '예매율': '4.9%'},
#  {'순위': '7위', '제목': '스즈메의 문단속', '평점': '7.5', '예매율': '4.4%'},
#  {'순위': '8위', '제목': '더 퍼스트 슬램덩크', '평점': '8.4', '예매율': '4.4%'},
#  {'순위': '9위', '제목': '킬링 로맨스', '평점': '5.8', '예매율': '3.7%'},
#  {'순위': ' 10위 ', '제목': '리바운드', '평점': '8.9', '예매율': '2.1%'},
#  {'순위': ' 11위 ', '제목': '라이스보이 슬립스', '평점': '9.3', '예매율': '2%'},
#  {'순위': ' 12위 ', '제목': '초속5센티미터', '평점': '8.0', '예매율': '1.4%'},
#  {'순위': ' 13위 ',
#   '제목': '콜드플레이 뮤직 오브 더 스피어스: 라이브 앳 리버 플레이트',
#   '평점': None,
#   '예매율': '0.7%'},
#  {'순위': ' 14위 ', '제목': '라라랜드', '평점': '8.1', '예매율': '0.7%'},
#  {'순위': ' 15위 ', '제목': '카운트', '평점': '8.3', '예매율': '0.6%'},
# ...

# %%
movieRank = movieInfo.find('span', attrs={'class':'num_rank01'}).get_text()
movieTitle = movieInfo.find('a', attrs={'class':'tit_main'}).get_text()
movieScore = movieInfo.find('em', attrs={'class':'rate'}).string
movieScoreCnt = movieInfo.find('a', attrs={'class':'link_count'}).string
movieOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})[1].get_text().strip()
movieTicketSales = movieInfo.find_all('dd', attrs={'class':'cont'})[0].text

# %%
for movieInfo in movieInfoList:
    movieRank = movieInfo.find('span', attrs={'class':'num_rank'}).get_text()
    movieTitle = movieInfo.find('a', attrs={'class':'tit_main'}).get_text()
    movieScore = movieInfo.find('em', attrs={'class':'rate'}).get_text()
    if len(movieScoreCnt) == 1:
        movieScoreCnt = movieInfo.find('a', attrs={'class':'link_count'}).get_text()
    else:
        movieScoreCnt = "X"
    movieTicketSales = movieInfo.find_all('dd', attrs={'class':'cont'}).get_text()
    movieOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})[1].get_text().strip()
    if len(movieOpenDate) > 1:
        movieOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})[1].get_text().strip()
        
    else
        movieOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})[0].get_text().strip()
